# %%
# 深拷贝、浅拷贝

# 1.浅拷贝
# 浅拷贝是对于一个对象的顶层拷贝，只拷贝了引用，没有拷贝内容

a=[11,22,33]
print(id(a))

b=a
print(id(b))

a.append(44)
print(a)
print(b)

print("------------------")
c={"name":"xiaomi"}
print(id(c))

d=c
print(id(d))

c['id']=100

print(c)
print(d)
# Out:
# 2416185884488
# 2416185884488
# [11, 22, 33, 44]
# [11, 22, 33, 44]
# ------------------
# 2416184540904
# 2416184540904
# {'name': 'xiaomi', 'id': 100}
# {'name': 'xiaomi', 'id': 100}

# %% [markdown]
# ## 深拷贝
# 深拷贝是对于一个对象所有层次的拷贝（递归）
#
# ![image.png](attachment:image.png)
#
# 进一步理解拷贝
